# %%
import numpy as np
import pandas as pd
import requests
import os
import json

# %%
congressapi = os.getenv('congressapi')
opensecretsapi = os.getenv('opensecretsapi')

# %% [markdown]
# # Congress Bills API for the 118th Congress

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
endpoint = f'/bill/{congress}'

# %%
root + endpoint
# Out:
# 'https://api.congress.gov/v3/bill/118'

# %%
parameters = {'format': 'json',
             'offset': 0,
             'limit': 250,
             'sort': 'updateDate+desc',
             'api_key': congressapi}

# %%
r = requests.get('http://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']
headers = {'User-Agent': useragent,
          'From': 'ynx9zm@virginia.edu'}

# %%
headers = {'User-Agent': useragent,
          'From': 'ynx9zm@virginia.edu'}

# %%
r = requests.get(root + endpoint,
                params = parameters,
                headers = headers)

# %%
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)

# %%
myjson
# Out:
# {'bills': [{'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '95',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Declaring a state of war between certain cartels and the United States of America and making provision to prosecute the same.',
#    'type': 'HJRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hjres/95?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '780',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the goals of "World Sight Day" by promoting the importance of accessible, affordable, and inclusive eye care.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/780?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '779',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Recognizing the importance of the National Park Service in preserving the legacy of LGBTQI+ people and honoring their contributions to American history through the preservation of historic places and landmarks.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/779?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '778',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Demanding Senator Tommy Tuberville stop threatening United States and Israel security.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/778?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '777',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Urging the Biden administration to demand the release of all hostages in Gaza.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/777?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '776',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Urging the Biden administration to rescind the release of $6,000,000,000 in frozen Iranian funds and to lawfully enforce the Taylor Force Act.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/776?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '775',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Condemning the New York City-Democratic Socialists of America (NYC-DSA) antisemitic and anti-Israel rally on October 8, 2023.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/775?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '774',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': "Recognizing the influx of known or suspected terrorists through America's northern border as a threat to national security.",
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/774?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '773',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Providing for the expulsion of Representative George Santos from the House of Representatives.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/773?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '772',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Censuring Representative Rashida Tlaib.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:02Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/772?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '771',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Standing with Israel as it defends itself against the barbaric war launched by Hamas and other terrorists.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:01Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/771?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5933',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Higher Education Act of 1965 to require additional information in disclosures of foreign gifts and contracts from foreign sources, restrict contracts with certain foreign entities and foreign countries of concern, require certain staff and faculty to report foreign gifts and contracts, and require disclosure of certain foreign investments within endowments.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5933?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5932',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To authorize additional assistance to Israel using assets confiscated from the Iran, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5932?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5931',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': "To require a briefing from a senior official of the Department of Defense on actions by the People's Republic of China in Africa that pose a threat to United States national security.",
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5931?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5930',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title 5, United States Code, to require a clarification of the underlying authority for a rulemaking.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5930?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5929',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend section 6906 of title 31, United States Code, to permanently authorize the Payment in Lieu of Taxes program.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5929?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5928',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Internal Revenue Code of 1986 to allow early childhood educators to take the educator expense deduction, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5928?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5927',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To require the Secretary of the Interior to withdraw certain documents relating to grizzly bears.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:04Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5927?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5926',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': "To require the review by the Committee on Foreign Investment in the United States of greenfield investments by the People's Republic of China.",
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5926?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5925',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To authorize the seizure of the property of certain sanctioned individuals for purposes of covering expenses relating to the Ukraine-Russia conflict, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5925?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5924',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title XVIII of the Social Security Act with respect to the timing of changes to the annual out-of-pocket threshold for the Medicare prescription drug benefit, and to amend title XI of such Act with respect to the timing of the Medicare drug price negotiation program.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5924?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5923',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To impose restrictions on correspondent and payable-through accounts in the United States with respect to Chinese financial institutions that conduct transactions involving the purchase of petroleum or petroleum products from Iran.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5923?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5922',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Food Security Act of 1985 to address emissions of certain greenhouse gasses and carbon storage through conservation incentive contracts.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5922?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5921',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To prohibit the Secretary of the Treasury from authorizing certain transactions by a United States financial institution in connection with Iran, to prevent the International Monetary Fund from providing financial assistance to Iran, to codify prohibitions on Export-Import Bank financing for the Government of Iran, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5921?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5920',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Internal Revenue Code of 1986 to allow married couples to apply the student loan interest deduction limitation separately to each spouse, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5920?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-11', 'text': 'Introduced in House'},
#    'number': '5919',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To require the Secretary of the Interior to conduct an assessment to identify locations in National Parks in which there is the greatest need for broadband internet access service and areas in National Parks in which there is the greatest need for cellular service, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:16:03Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5919?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10',
#     'text': 'Referred to the Subcommittee on Highways and Transit.'},
#    'number': '5760',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Climate Resilience Workforce Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:13:47Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5760?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '770',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Condemning an act of war against Israel by Hamas, the Palestinian Islamic Jihad, and associated forces, and for other purposes.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:16Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/770?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '769',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the designation of October 10, 2023 as "Real Women\'s Day".',
#    'type': 'HRES',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/769?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '768',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Standing with Israel as it defends itself against the barbaric war launched by Hamas and other terrorists.',
#    'type': 'HRES',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/768?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5918',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Making supplemental appropriations for the fiscal year ending September 30, 2024.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5918?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5917',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Sanctioning the Use of Civilians as Defenseless Shields Act to modify and extend that Act, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5917?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5916',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To require the Secretary of Agriculture to designate and maintain at least 20 percent of the total number of trails in the Shawnee National Forest for trail riding by covered vehicles, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5916?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5915',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Department of Agriculture Reorganization Act of 1994 to improve the Office of Urban Agriculture and Innovative Production, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5915?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5914',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title 38, United States Code, to improve the processes to approve programs of education for purposes of the educational assistance programs of the Department of Veterans Affairs, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5914?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-10', 'text': 'Introduced in House'},
#    'number': '5913',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title 38, United States Code, to improve employment services for veterans by consolidating various programs in the Department of Veterans Affairs, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:41Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5913?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06',
#     'text': 'Became Public Law No: 118-17.'},
#    'number': '5110',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Protecting Hunting Heritage and Education Act',
#    'type': 'HR',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T14:30:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5110?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06',
#     'text': 'Became Public Law No: 118-19.'},
#    'number': '2795',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend title 38, United States Code, to extend and modify certain authorities and requirements relating to the Department of Veterans Affairs, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:15:13Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/2795?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06',
#     'text': 'Became Public Law No: 118-18.'},
#    'number': '112',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend title 38, United States Code, to strengthen benefits for children of Vietnam veterans born with spina bifida, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/112?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06',
#     'text': 'Sponsor introductory remarks on measure. (CR E938)'},
#    'number': '5906',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title XI of the Social Security Act to exclude expenditures attributable to a State medicaid fraud control unit from the payment limits under Medicaid for Guam, the Northern Mariana Islands, and American Samoa.',
#    'type': 'HR',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T12:28:47Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5906?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '767',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the designation of the week beginning on October 8, 2023, as "National Wildlife Refuge Week".',
#    'type': 'HRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:57Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/767?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '766',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Supporting the designation of October 7, 2023, as National Ostomy Awareness Day.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:16Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/766?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '765',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Urging the people of the United States to observe the month of October 2023 as Italian and Italian-American Heritage Month.',
#    'type': 'HRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:15Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/765?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '764',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the recognition of Christopher Columbus and his impact on the Italian-American community, and recognizing the second Monday in October as "Columbus Day".',
#    'type': 'HRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/764?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '763',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': "Reaffirming the United States commitment to respecting the sovereignty of Mexico and condemning calls for military action in Mexico without Mexico's consent and congressional authorization.",
#    'type': 'HRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/763?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '762',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for increasing the number of Latino students and young professionals entering careers in science, technology, engineering, and mathematics fields.',
#    'type': 'HRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/762?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '761',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Amending the Rules of the House of Representatives to limit the eligibility for nomination to serve as Speaker of the House of Representatives to Members and Members-elect of the House.',
#    'type': 'HRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/761?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '73',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Condemning the Cuban regime and the Chinese Communist Party for their reported intent to build a joint military training base on the island of Cuba, 100 miles from the United States.',
#    'type': 'HCONRES',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:16Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hconres/73?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '72',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Recognizing the significance of equal pay and the disparity in wages paid to Latina women in comparison to men.',
#    'type': 'HCONRES',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hconres/72?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5912',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To continue in effect certain Executive orders imposing sanctions with respect to Iran, to prevent the waiver of certain sanctions imposed by the United States with respect to Iran until the Government of Iran ceases to attempt to assassinate United States officials, other United States citizens, and Iranian nationals residing in the United States, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5912?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5911',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Internal Revenue Code of 1986 to exclude strike benefits from gross income.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5911?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5910',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To prioritize educating and training for existing and new environmental health professionals.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5910?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5909',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title XXVII of the Public Health Service Act to limit cost sharing for prenatal services in certain circumstances.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5909?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5908',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To provide funding to summer youth employment programs to expand the availability of subsidized jobs for youths and to develop innovative program activities that improve academic, economic, and criminal justice outcomes for youths, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5908?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5907',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To criminalize transnational repression, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5907?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5905',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To protect access to kratom.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5905?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5904',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend title 38, United States Code, to improve services provided by the Department of Veterans Affairs for veteran families, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5904?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5903',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To authorize the International Boundary and Water Commission to accept funds for activities relating to wastewater treatment and flood control works, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5903?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5902',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Higher Education Act of 1965 to require staff and faculty to report foreign gifts and contracts.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5902?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5901',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Public Health Service Act to encourage programs to address college athlete mental health.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5901?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5900',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To prohibit individuals from publicizing certain information relating to security clearances.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5900?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5899',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To reauthorize the Southeast Crescent Regional Commission, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5899?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5898',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To authorize the Secretary of Defense to enter into a limited number of cost-plus incentive-fee contracts for the Sentinel Intercontinental Ballistic Missile program, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:57Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5898?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5897',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Animal Welfare Act to direct the Secretary of Agriculture to establish a program under which the Secretary will award grants to entities for purposes of supporting the capability of such entities to provide care to animals in their care, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:57Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5897?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5896',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To award a congressional gold medal to the United Negro College Fund, Inc. and the 2 institutions that make up its membership on the occasion of its 80th year of existence.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5896?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5895',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To amend the Higher Education Act of 1965 to provide for additional uses of funds for grants to strengthen historically Black colleges and universities, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:59Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5895?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5894',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Making appropriations for the Departments of Labor, Health and Human Services, and Education, and related agencies for the fiscal year ending September 30, 2024, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:57Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5894?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-06', 'text': 'Introduced in House'},
#    'number': '5893',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Making appropriations for the Departments of Commerce and Justice, Science, and Related Agencies for the fiscal year ending September 30, 2024, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T07:15:57Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5893?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4957)'},
#    'number': '405',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution expressing support for the designation of September 30, 2023, as "National Veterans Suicide Prevention Day".',
#    'type': 'SRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T16:00:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/405?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4957)'},
#    'number': '404',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating October 4, 2023, as "Energy Efficiency Day" in celebration of the economic and environmental benefits that have been driven by private sector innovation and Federal energy efficiency policies.',
#    'type': 'SRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T16:15:17Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/404?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4957)'},
#    'number': '403',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution recognizing the 10th anniversary of the USA Rice-Ducks Unlimited Rice Stewardship Partnership.',
#    'type': 'SRES',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T17:15:14Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/403?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4956-4957)'},
#    'number': '402',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating October 26, 2023, as the "Day of the Deployed".',
#    'type': 'SRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T16:00:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/402?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4956)'},
#    'number': '401',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution honoring the life, legacy, and contributions of James William Buffett.',
#    'type': 'SRES',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T15:45:15Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/401?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958-4959; text: CR S4955-4956)'},
#    'number': '400',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution honoring the life and legacy of Dianne Feinstein, the late Senator for the State of California.',
#    'type': 'SRES',
#    'updateDate': '2023-10-06',
#    'updateDateIncludingText': '2023-10-06T02:43:56Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/400?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4955)'},
#    'number': '399',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution expressing support for the designation of October 1 through October 7, 2023, as "National 4-H Week".',
#    'type': 'SRES',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T17:15:13Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/399?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4958; text: CR S4954-4955)'},
#    'number': '398',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating the week of September 25 through September 29, 2023, as "National Clean Energy Week".',
#    'type': 'SRES',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T16:00:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/398?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#    'number': '3039',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Federal Kratom Consumer Protection Act',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:15:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3039?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#    'number': '3038',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'American Offshore Worker Fairness Act',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:15:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3038?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Finance.'},
#    'number': '3037',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'SEED Act',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:30:39Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3037?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#    'number': '3036',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Mountain View Corridor Completion Act',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:15:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3036?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Message on Senate action sent to the House.'},
#    'number': '394',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution honoring the life of James L. Buckley, former Senator for the State of New York.',
#    'type': 'SRES',
#    'updateDate': '2023-10-06',
#    'updateDateIncludingText': '2023-10-06T02:58:51Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/394?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Message on Senate action sent to the House.'},
#    'number': '393',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution to honor the life and death of Duncan McLauchlin ("Lauch") Faircloth, former Senator for the State of North Carolina.',
#    'type': 'SRES',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T04:13:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/393?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Message on Senate action sent to the House.'},
#    'number': '2231',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Maternal and Child Health Stillbirth Prevention Act',
#    'type': 'S',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T04:14:00Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/2231?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S4952-4953)'},
#    'number': '395',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution recognizing the contributions of the Montagnard indigenous tribespeople of the Central Highlands of Vietnam to the United States Armed Forces during the Vietnam War, and condemning the ongoing violation of human rights by the Government of the Socialist Republic of Vietnam.',
#    'type': 'SRES',
#    'updateDate': '2023-10-10',
#    'updateDateIncludingText': '2023-10-10T17:15:13Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sres/395?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#    'number': '3034',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Meals for At-Risk Americans Act of 2023',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:15:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3034?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S4957-4958)'},
#    'number': '21',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the significance of equal pay and the disparity in wages paid to Latina women in comparison to men.',
#    'type': 'SCONRES',
#    'updateDate': '2023-10-06',
#    'updateDateIncludingText': '2023-10-06T11:00:23Z',
#    'url': 'https://api.congress.gov/v3/bill/118/sconres/21?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#    'number': '3033',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Pecos Watershed Protection Act',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:26Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3033?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#    'number': '3035',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Protecting Our Kids from Harmful Research Act',
#    'type': 'S',
#    'updateDate': '2023-10-07',
#    'updateDateIncludingText': '2023-10-07T12:15:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3035?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on the Judiciary.'},
#    'number': '3032',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Cerro Pelado Fire Assistance Act',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:26Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3032?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on the Judiciary.'},
#    'number': '3031',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Hermit’s Peak/Calf Canyon Claims Extension Act',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:26Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3031?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
#     'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#    'number': '3030',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Encouraging Public Offerings Act of 2023',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:26Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/3030?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-10-04',
# ...
#     'text': 'Referred to the Subcommittee on Economic Development, Public Buildings, and Emergency Management.'},
#    'number': '5825',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'CEDS Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T20:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5825?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Subcommittee on Economic Development, Public Buildings, and Emergency Management.'},
#    'number': '5812',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'No Glory for Hate Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5812?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Subcommittee on Economic Development, Public Buildings, and Emergency Management.'},
#    'number': '5799',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'James R. Dominguez Memorial Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T07:15:42Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5799?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Subcommittee on Economic Development, Public Buildings, and Emergency Management.'},
#    'number': '5795',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Natural Disaster Transparency Enhancement Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5795?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Reported (Amended) by the Committee on Ways and Means. H. Rept. 118-231, Part I.'},
#    'number': '4822',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Health Care Price Transparency Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T13:57:47Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/4822?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#    'number': '2998',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Land-Grant Research Equity and Accountability Act',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:24Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/2998?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'actionTime': '12:08:46',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '742',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing the profound sorrow of the House of Representatives on the death of the Honorable Dianne Goldman Berman Feinstein.',
#    'type': 'HRES',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T13:24:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/742?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'actionTime': '12:01:47',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '741',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Providing for consideration of the bill (H.R. 5525) making continuing appropriations for fiscal year 2024, and for other purposes.',
#    'type': 'HRES',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T17:45:25Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/741?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#    'number': '2997',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend title 40, United States Code, to increase the mileage of the Appalachian Development Highway System to provide for improvements to and expansion of Corridor K in North Carolina, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/2997?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#    'number': '2996',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Rural Microentrepreneur Assistance Act of 2023',
#    'type': 'S',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T12:45:24Z',
#    'url': 'https://api.congress.gov/v3/bill/118/s/2996?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Energy and Commerce.'},
#    'number': '5858',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Ovarian, Cervical, and Endometrial Cancer Awareness Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T08:45:21Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5858?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Committee on the Judiciary, and in addition to the Committee on Foreign Affairs, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#    'number': '5838',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To improve immigration adjudicatory capacity, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T07:15:43Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5838?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on House Administration.'},
#    'number': '5853',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'No Budget, No Pay Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5853?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Homeland Security.'},
#    'number': '5840',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Transportation Security Screening Modernization Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T20:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5840?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Energy and Commerce.'},
#    'number': '5829',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Health Care Practitioner Disaster Protection Act',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5829?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Financial Services.'},
#    'number': '5828',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'NFIP Extension Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T14:15:39Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5828?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Oversight and Accountability.'},
#    'number': '752',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Recognizing and honoring the first responders and those who lost their lives in the Maui wildfires in August 2023 that affected thousands of people.',
#    'type': 'HRES',
#    'updateDate': '2023-10-06',
#    'updateDateIncludingText': '2023-10-06T12:45:16Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/752?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Education and the Workforce.'},
#    'number': '5852',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': '21st Century SKILLS Act',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T07:15:58Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5852?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Committee on Foreign Affairs, and in addition to the Committees on Education and the Workforce, and the Judiciary, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#    'number': '5856',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Frederick Douglass Trafficking Victims Prevention and Protection Reauthorization Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-12',
#    'updateDateIncludingText': '2023-10-12T08:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5856?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Energy and Commerce.'},
#    'number': '5830',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'American Genetic Privacy Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5830?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Committee on Foreign Affairs, and in addition to the Committees on Intelligence (Permanent Select), and the Budget, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#    'number': '5833',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Protection of Saudi Dissidents Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T20:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5833?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Oversight and Accountability.'},
#    'number': '5832',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Keep the Watchdogs Running Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5832?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Homeland Security.'},
#    'number': '5839',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Maritime Border Security Technology Improvement Act',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T20:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5839?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': "Referred to the House Committee on Veterans' Affairs."},
#    'number': '750',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Recognizing Operation Green Light for Veterans for supporting veterans and raising awareness about important county resources available to help veterans transition to civilian life.',
#    'type': 'HRES',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T21:15:27Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/750?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Financial Services.'},
#    'number': '5837',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': "Protecting America's Property Rights Act",
#    'type': 'HR',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T17:45:22Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5837?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Financial Services.'},
#    'number': '5843',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'NFIP Stopgap Act of 2023',
#    'type': 'HR',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T21:00:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5843?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the Committee on Financial Services, and in addition to the Committee on Ways and Means, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#    'number': '5827',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'To promote the establishment of resident organizations and provide additional amounts for tenant organizations, and for other purposes.',
#    'type': 'HR',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T13:24:20Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hr/5827?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Oversight and Accountability.'},
#    'number': '751',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the designation of October 1, 2023, as "National Animal Rescue Day" to create awareness of the importance of animal adoption, to educate on the importance of spaying and neutering animals, and to encourage animal adoptions throughout the United States.',
#    'type': 'HRES',
#    'updateDate': '2023-10-04',
#    'updateDateIncludingText': '2023-10-04T13:49:12Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/751?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Oversight and Accountability.'},
#    'number': '70',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for designation of the first Friday of October as "Manufacturing Day".',
#    'type': 'HCONRES',
#    'updateDate': '2023-10-11',
#    'updateDateIncludingText': '2023-10-11T07:15:16Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hconres/70?format=json'},
#   {'congress': 118,
#    'latestAction': {'actionDate': '2023-09-29',
#     'text': 'Referred to the House Committee on Education and the Workforce.'},
#    'number': '743',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Expressing support for the designation of September 2023 as "National Workforce Development Month".',
#    'type': 'HRES',
#    'updateDate': '2023-10-05',
#    'updateDateIncludingText': '2023-10-05T07:15:24Z',
#    'url': 'https://api.congress.gov/v3/bill/118/hres/743?format=json'}],
#  'pagination': {'count': 10380,
#   'next': 'https://api.congress.gov/v3/bill/118?sort=updateDate+desc&offset=250&limit=250&format=json'},
#  'request': {'congress': '118',
#   'contentType': 'application/json',
#   'format': 'json'}}

# %%
myjson['bills'][0]['number']
# Out:
# '95'

# %%
[x['number'] for x in myjson['bills']]
# Out:
# ['95',
#  '780',
#  '779',
#  '778',
#  '777',
#  '776',
#  '775',
#  '774',
#  '773',
#  '772',
#  '771',
#  '5933',
#  '5932',
#  '5931',
#  '5930',
#  '5929',
#  '5928',
#  '5927',
#  '5926',
#  '5925',
#  '5924',
#  '5923',
#  '5922',
#  '5921',
#  '5920',
#  '5919',
#  '5760',
#  '770',
#  '769',
#  '768',
#  '5918',
#  '5917',
#  '5916',
#  '5915',
#  '5914',
#  '5913',
#  '5110',
#  '2795',
#  '112',
#  '5906',
#  '767',
#  '766',
#  '765',
#  '764',
#  '763',
#  '762',
#  '761',
#  '73',
#  '72',
#  '5912',
#  '5911',
#  '5910',
#  '5909',
#  '5908',
#  '5907',
#  '5905',
#  '5904',
#  '5903',
#  '5902',
#  '5901',
#  '5900',
#  '5899',
#  '5898',
#  '5897',
#  '5896',
#  '5895',
#  '5894',
#  '5893',
#  '405',
#  '404',
#  '403',
#  '402',
#  '401',
#  '400',
#  '399',
#  '398',
#  '3039',
#  '3038',
#  '3037',
#  '3036',
#  '394',
#  '393',
#  '2231',
#  '395',
#  '3034',
#  '21',
#  '3033',
#  '3035',
#  '3032',
#  '3031',
#  '3030',
#  '397',
#  '3029',
#  '396',
#  '3028',
#  '3027',
#  '3026',
#  '3025',
#  '3024',
#  '1573',
#  '2415',
#  '1624',
#  '3023',
#  '3022',
#  '3021',
#  '3020',
#  '3019',
#  '3018',
#  '3017',
#  '3016',
#  '3015',
#  '5702',
#  '5697',
#  '5682',
#  '3014',
#  '3013',
#  '3012',
#  '3011',
#  '3010',
#  '3009',
#  '156',
#  '3008',
#  '4665',
#  '3843',
#  '1822',
#  '1443',
#  '1137',
#  '1464',
#  '757',
#  '292',
#  '996',
#  '2379',
#  '3944',
#  '4502',
#  '3007',
#  '3006',
#  '3005',
#  '311',
#  '3004',
#  '5692',
#  '699',
#  '756',
#  '4364',
#  '2934',
#  '5865',
#  '5879',
#  '5881',
#  '5880',
#  '5877',
#  '5876',
#  '759',
#  '5878',
#  '5874',
#  '758',
#  '5875',
#  '5871',
#  '4394',
#  '724',
#  '5677',
#  '760',
#  '71',
#  '5892',
#  '5891',
#  '5890',
#  '5889',
#  '5888',
#  '5887',
#  '5886',
#  '5885',
#  '5884',
#  '5883',
#  '5882',
#  '475',
#  '3943',
#  '3557',
#  '3385',
#  '5859',
#  '5842',
#  '5835',
#  '4467',
#  '2577',
#  '5863',
#  '5873',
#  '5866',
#  '5870',
#  '5862',
#  '754',
#  '5861',
#  '755',
#  '5872',
#  '5867',
#  '5869',
#  '5868',
#  '5864',
#  '5653',
#  '5860',
#  '392',
#  '391',
#  '390',
#  '310',
#  '389',
#  '3935',
#  '2357',
#  '3003',
#  '753',
#  '388',
#  '3002',
#  '3571',
#  '3001',
#  '3496',
#  '3506',
#  '2195',
#  '3000',
#  '3578',
#  '1505',
#  '46',
#  '387',
#  '2999',
#  '386',
#  '5525',
#  '5825',
#  '5812',
#  '5799',
#  '5795',
#  '4822',
#  '2998',
#  '742',
#  '741',
#  '2997',
#  '2996',
#  '5858',
#  '5838',
#  '5853',
#  '5840',
#  '5829',
#  '5828',
#  '752',
#  '5852',
#  '5856',
#  '5830',
#  '5833',
#  '5832',
#  '5839',
#  '750',
#  '5837',
#  '5843',
#  '5827',
#  '751',
#  '70',
#  '743']

# %%
with open('bills.json', 'w') as f:
    json.dump(myjson, f)

# %%
billsdf = pd.json_normalize(myjson,
                           record_path = ['bills'])

# %%
billsdf
# Out:
#      congress number originChamber originChamberCode  \
# 0         118    475        Senate                 S
# 1         118    354        Senate                 S
# 2         118    353        Senate                 S
# 3         118   3935         House                 H
# 4         118   1418         House                 H
# ..        ...    ...           ...               ...
# 245       118   5473         House                 H
# 246       118   5465         House                 H
# 247       118   5457         House                 H
# 248       118      9        Senate                 S
# 249       118   2544         House                 H
#
#                                                  title   type  updateDate  \
# 0    A bill to designate the clinic of the Departme...      S  2023-09-21
# 1    A resolution congratulating the Louisiana Stat...   SRES  2023-09-21
# 2    A resolution expressing support for the design...   SRES  2023-09-21
# 3    Securing Growth and Robust Leadership in Ameri...     HR  2023-09-21
# 4    Animal Drug and Animal Generic Drug User Fee A...     HR  2023-09-21
# ..                                                 ...    ...         ...
# 245          Promoting Resilient Buildings Act of 2023     HR  2023-09-20
# 246   Congressional Access to Bureaucratic Offices Act     HR  2023-09-21
# 247  Carbon Dioxide Removal Research and Developmen...     HR  2023-09-20
# 248  A joint resolution providing for congressional...  SJRES  2023-09-20
# 249  Securing the U.S. Organ Procurement and Transp...     HR  2023-09-20
#
#     updateDateIncludingText  \
# 0      2023-09-21T19:43:44Z
# 1      2023-09-21T12:13:40Z
# 2      2023-09-21T12:13:40Z
# 3      2023-09-21T04:13:50Z
# 4      2023-09-21T04:13:50Z
# ..                      ...
# 245    2023-09-20T13:40:22Z
# 246    2023-09-21T11:30:24Z
# 247    2023-09-20T13:40:22Z
# 248    2023-09-20T14:08:25Z
# 249    2023-09-20T14:04:13Z
#
#                                                    url  \
# 0    https://api.congress.gov/v3/bill/118/s/475?for...
# 1    https://api.congress.gov/v3/bill/118/sres/354?...
# 2    https://api.congress.gov/v3/bill/118/sres/353?...
# 3    https://api.congress.gov/v3/bill/118/hr/3935?f...
# 4    https://api.congress.gov/v3/bill/118/hr/1418?f...
# ..                                                 ...
# 245  https://api.congress.gov/v3/bill/118/hr/5473?f...
# 246  https://api.congress.gov/v3/bill/118/hr/5465?f...
# 247  https://api.congress.gov/v3/bill/118/hr/5457?f...
# 248  https://api.congress.gov/v3/bill/118/sjres/9?f...
# 249  https://api.congress.gov/v3/bill/118/hr/2544?f...
#
#     latestAction.actionDate  \
# 0                2023-09-21
# 1                2023-09-20
# 2                2023-09-20
# 3                2023-09-20
# 4                2023-09-20
# ..                      ...
# 245              2023-09-15
# 246              2023-09-15
# 247              2023-09-15
# 248              2023-09-14
# 249              2023-09-14
#
#                                      latestAction.text latestAction.actionTime
# 0                              Presented to President.                     NaN
# 1    Submitted in the Senate, considered, and agree...                     NaN
# 2    Submitted in the Senate, considered, and agree...                     NaN
# 3    Read the first time. Placed on Senate Legislat...                     NaN
# 4    Read twice. Placed on Senate Legislative Calen...                     NaN
# ..                                                 ...                     ...
# 245  Referred to the Subcommittee on Economic Devel...                     NaN
# 246  Referred to the Subcommittee on Economic Devel...                     NaN
# 247  Referred to the Subcommittee on Water Resource...                     NaN
# 248                            Presented to President.                     NaN
# 249                            Presented to President.                     NaN
#
# [250 rows x 12 columns]

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = "s"
endpoint = f'/bill/{congress}/{bill_type}'
r = requests.get('http://httpbin.org/user-agent')
user_agent = json.loads(r.text)['user-agent']
headers = {'User-Agent': user_agent,
          'From': 'ynx9zm@virginia.edu'}


senate_bills=[]

for i in range(0, 1001, 250):
    parameters = {'format': 'json',
                    'offset': i,
                  'limit': 250,
                  'sort': 'updateDate+desc',
                  'api_key': congressapi
    }
    
    r = requests.get(root + endpoint, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    bills = myjson['bills']
    senate_bills.append(bills)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 bill_type = "s"
#       4 endpoint = f'/bill/{congress}/{bill_type}'
# ----> 5 r = requests.get('http://httpbin.org/user-agent')
#       6 user_agent = json.loads(r.text)['user-agent']
#       7 headers = {'User-Agent': user_agent,
#       8           'From': 'ynx9zm@virginia.edu'}
#
# NameError: name 'requests' is not defined

# %%
df1=pd.DataFrame.from_dict(senate_bills[0])
df2=pd.DataFrame.from_dict(senate_bills[1])
df3=pd.DataFrame.from_dict(senate_bills[2])
df4=pd.DataFrame.from_dict(senate_bills[3])
df5=pd.DataFrame.from_dict(senate_bills[4])
frames = [df1,df2,df3,df4,df5]
senate_bills = pd.concat(frames,ignore_index=True)

# %%
senate_bills
# Out:
#       congress                                       latestAction number  \
# 0          118  {'actionDate': '2023-09-27', 'text': 'Read twi...   2961
# 1          118  {'actionDate': '2023-09-27', 'text': 'Read twi...   2960
# 2          118  {'actionDate': '2023-09-27', 'text': 'Placed o...    654
# 3          118  {'actionDate': '2023-09-27', 'text': 'Placed o...   2959
# 4          118  {'actionDate': '2023-09-27', 'text': 'Placed o...   2958
# ...        ...                                                ...    ...
# 1245       118  {'actionDate': '2023-06-08', 'text': 'Read twi...   1903
# 1246       118  {'actionDate': '2023-06-08', 'text': 'Read twi...   1899
# 1247       118  {'actionDate': '2023-06-08', 'text': 'Read twi...   1897
# 1248       118  {'actionDate': '2023-06-08', 'text': 'Read twi...   1894
# 1249       118  {'actionDate': '2023-06-08', 'text': 'Read twi...   1893
#
#      originChamber originChamberCode  \
# 0           Senate                 S
# 1           Senate                 S
# 2           Senate                 S
# 3           Senate                 S
# 4           Senate                 S
# ...            ...               ...
# 1245        Senate                 S
# 1246        Senate                 S
# 1247        Senate                 S
# 1248        Senate                 S
# 1249        Senate                 S
#
#                                                   title type  updateDate  \
# 0     A bill to ensure greater equity in Federal dis...    S  2023-09-28
# 1     A bill to modify certain notice requirements, ...    S  2023-09-28
# 2     Delaware River Basin Conservation Reauthorizat...    S  2023-09-28
# 3     An original bill to amend the Comprehensive En...    S  2023-09-28
# 4     An original bill to amend the Coastal Barrier ...    S  2023-09-28
# ...                                                 ...  ...         ...
# 1245                                            CCP Act    S  2023-09-22
# 1246                  Hydrogen Aviation Development Act    S  2023-09-22
# 1247  Enhancing Southbound Inspections to Combat Car...    S  2023-09-22
# 1248             Colorectal Cancer Payment Fairness Act    S  2023-09-22
# 1249  Resources for Victims of Gun Violence Act of 2023    S  2023-09-22
#
#      updateDateIncludingText  \
# 0       2023-09-28T04:16:00Z
# 1       2023-09-28T04:16:00Z
# 2       2023-09-28T04:14:08Z
# 3       2023-09-28T04:16:00Z
# 4       2023-09-28T04:16:00Z
# ...                      ...
# 1245    2023-09-22T13:17:09Z
# 1246    2023-09-22T13:17:09Z
# 1247    2023-09-22T12:40:24Z
# 1248    2023-09-22T13:17:08Z
# 1249    2023-09-22T13:17:08Z
#
#                                                     url
# 0     https://api.congress.gov/v3/bill/118/s/2961?fo...
# 1     https://api.congress.gov/v3/bill/118/s/2960?fo...
# 2     https://api.congress.gov/v3/bill/118/s/654?for...
# 3     https://api.congress.gov/v3/bill/118/s/2959?fo...
# 4     https://api.congress.gov/v3/bill/118/s/2958?fo...
# ...                                                 ...
# 1245  https://api.congress.gov/v3/bill/118/s/1903?fo...
# 1246  https://api.congress.gov/v3/bill/118/s/1899?fo...
# 1247  https://api.congress.gov/v3/bill/118/s/1897?fo...
# 1248  https://api.congress.gov/v3/bill/118/s/1894?fo...
# 1249  https://api.congress.gov/v3/bill/118/s/1893?fo...
#
# [1250 rows x 10 columns]

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = "s"
cosponsors=[]
for i in range(0, 100):
    if i % 10 ==0:
        print(f"collecting bill number {i}")
    bill_number = senate_bills.iloc[i]['number']
    endpoint = f'/bill/{congress}/{bill_type}/{bill_number}/cosponsors'
    parameters = {'format': 'json',
                  'sort': 'updateDate+desc',
                  'api_key': congressapi
    }
    
    r = requests.get(root + endpoint, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    cosponsor = myjson['cosponsors']
    cosponsors.append({"Bill Number": f"S {bill_number}", "Cosponsors": cosponsor})
cosponsors = pd.DataFrame.from_dict(cosponsors)
cosponsors
# Out:
# collecting bill number 0
# collecting bill number 10
# collecting bill number 20
# collecting bill number 30
# collecting bill number 40
# collecting bill number 50
# collecting bill number 60
# collecting bill number 70
# collecting bill number 80
# collecting bill number 90
#    Bill Number                                         Cosponsors
# 0       S 2961  [{'bioguideId': 'B001288', 'firstName': 'Cory'...
# 1       S 2960  [{'bioguideId': 'S001203', 'firstName': 'Tina'...
# 2        S 654  [{'bioguideId': 'B001288', 'firstName': 'Cory'...
# 3       S 2959                                                 []
# 4       S 2958                                                 []
# ..         ...                                                ...
# 95      S 2875                                                 []
# 96      S 1657  [{'bioguideId': 'K000377', 'firstName': 'Mark'...
# 97      S 2216                                                 []
# 98      S 1097  [{'bioguideId': 'F000062', 'firstName': 'Diann...
# 99      S 2149                                                 []
#
# [100 rows x 2 columns]

# %%
root = 'http://www.opensecrets.org/api/'
parameters = { 'method':'getlegislators',
                  'apikey': opensecretsapi,
                  'id':'VA',
                    'output':'json'
    }
headers = {'User-Agent': user_agent,
          'From': 'ynx9zm@virginia.edu'}
r = requests.get(root, params = parameters, headers = headers)
myjson = json.loads(r.text)

 
cids = []
for i in range(0, len(myjson['response']['legislator'])):
    cid = myjson['response']['legislator'][i]['@attributes']['cid']
    cids.append(cid)
cids
# Out:
# ['N00029459',
#  'N00048315',
#  'N00002147',
#  'N00051961',
#  'N00045557',
#  'N00042296',
#  'N00041418',
#  'N00036018',
#  'N00032029',
#  'N00041002',
#  'N00029891',
#  'N00033177',
#  'N00002097']

# %%
financial_information = []
for i in range(0, len(cids)):
    parameters = { 'method':'memPFDprofile',
                  'apikey': opensecretsapi,
                  'cid':cids[i],
                    'output':'json'}
    r = requests.get(root, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    data = myjson['response']['member_profile']
    financial_information.append({'CID':cids[i],'Financial Information':data})
financial_information=pd.DataFrame.from_dict(financial_information)
financial_information
# Out:
#           CID                              Financial Information
# 0   N00029459  {'@attributes': {'name': 'Wittman, Rob', 'data...
# 1   N00048315  {'@attributes': {'name': '', 'data_year': '201...
# 2   N00002147  {'@attributes': {'name': 'Scott, Bobby', 'data...
# 3   N00051961  {'@attributes': {'name': '', 'data_year': '201...
# 4   N00045557  {'@attributes': {'name': '', 'data_year': '201...
# 5   N00042296  {'@attributes': {'name': '', 'data_year': '201...
# 6   N00041418  {'@attributes': {'name': '', 'data_year': '201...
# 7   N00036018  {'@attributes': {'name': '', 'data_year': '201...
# 8   N00032029  {'@attributes': {'name': 'Griffith, Morgan', '...
# 9   N00041002  {'@attributes': {'name': '', 'data_year': '201...
# 10  N00029891  {'@attributes': {'name': 'Connolly, Gerry', 'd...
# 11  N00033177  {'@attributes': {'name': '', 'data_year': '201...
# 12  N00002097  {'@attributes': {'name': 'Warner, Mark', 'data...
